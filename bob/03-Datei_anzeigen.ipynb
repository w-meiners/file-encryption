# %% [markdown]
# Anzeigen, was Bob von Alice erhalten hat:

# %%
from PIL import Image

image = Image.open('Rätsel.png')
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=3070x1658 at 0x7FB66ED9DA90>
